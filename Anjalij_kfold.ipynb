# %%
##importing the libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
##Loading the Titanic dataset

# %%
data = pd.read_csv("titanic_dataset.csv")

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ##Setting Passenger_ID as the index Column

# %%
data.set_index("PassengerId",inplace=True)

# %%
data.isnull().sum() ##Checking for the null values
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %% [markdown]
# ##Preprocessing

# %%
data["Embarked"].fillna("No value", inplace = True)

# %%
plt.hist(data['Age'])
plt.show()

# %%
from sklearn.impute import SimpleImputer

# %%
num_cols=data[['Age']]

# %%
imputer = SimpleImputer(missing_values=np.nan,strategy='mean') ##Filling the missing values in Age with mean
imputer=imputer.fit(num_cols)
num_cols = imputer.transform(num_cols)

# %%
num_cols=pd.DataFrame(num_cols,columns=[['Age']])

# %%
num_cols.head()
# Out:
#     Age
# 0  22.0
# 1  38.0
# 2  26.0
# 3  35.0
# 4  35.0

# %%
num_cols.index = np.arange(1, len(num_cols) + 1)

# %%
num_cols.head()
# Out:
#     Age
# 1  22.0
# 2  38.0
# 3  26.0
# 4  35.0
# 5  35.0

# %%
data.drop(['Age'],axis=1,inplace=True)

# %%
data.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex  SibSp  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male      1
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1
# 3                                       Heikkinen, Miss. Laina  female      0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1
# 5                                     Allen, Mr. William Henry    male      0
#
#              Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                0         A/5 21171   7.2500   NaN        S
# 2                0          PC 17599  71.2833   C85        C
# 3                0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
data=pd.concat([num_cols,data],axis=1) ##joining the num_cols with data

# %%
data.drop(['Cabin'],axis=1,inplace=True)##Removing the cabin column since it has more null values

# %%
data.isnull().sum()
# Out:
# (Age,)      0
# Survived    0
# Pclass      0
# Name        0
# Sex         0
# SibSp       0
# Parch       0
# Ticket      0
# Fare        0
# Embarked    0
# dtype: int64

# %%
data.head()
# Out:
#    (Age,)  Survived  Pclass  \
# 1    22.0         0       3
# 2    38.0         1       1
# 3    26.0         1       3
# 4    35.0         1       1
# 5    35.0         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 1                            Braund, Mr. Owen Harris    male      1      0
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 3                             Heikkinen, Miss. Laina  female      0      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 5                           Allen, Mr. William Henry    male      0      0
#
#              Ticket     Fare Embarked
# 1         A/5 21171   7.2500        S
# 2          PC 17599  71.2833        C
# 3  STON/O2. 3101282   7.9250        S
# 4            113803  53.1000        S
# 5            373450   8.0500        S

# %%
data.drop(['Ticket'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    (Age,)  Survived  Pclass  \
# 1    22.0         0       3
# 2    38.0         1       1
# 3    26.0         1       3
# 4    35.0         1       1
# 5    35.0         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 1                            Braund, Mr. Owen Harris    male      1      0
# 2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 3                             Heikkinen, Miss. Laina  female      0      0
# 4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 5                           Allen, Mr. William Henry    male      0      0
#
#       Fare Embarked
# 1   7.2500        S
# 2  71.2833        C
# 3   7.9250        S
# 4  53.1000        S
# 5   8.0500        S

# %% [markdown]
# ##Encoding

# %%
data.shape
# Out:
# (891, 9)

# %%
data.Name.nunique()
# Out:
# 891

# %%
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
data['Name']= label_encoder.fit_transform(data['Name'])

# %%
data=pd.get_dummies(data)

# %%
data.head()
# Out:
#    (Age,)  Survived  Pclass  Name  SibSp  Parch     Fare  Sex_female  \
# 1    22.0         0       3   108      1      0   7.2500           0
# 2    38.0         1       1   190      1      0  71.2833           1
# 3    26.0         1       3   353      0      0   7.9250           1
# 4    35.0         1       1   272      1      0  53.1000           1
# 5    35.0         0       3    15      0      0   8.0500           0
#
#    Sex_male  Embarked_C  Embarked_No value  Embarked_Q  Embarked_S
# 1         1           0                  0           0           1
# 2         0           1                  0           0           0
# 3         0           0                  0           0           1
# 4         0           0                  0           0           1
# 5         1           0                  0           0           1

# %%
X=data.drop('Survived',axis=1)
y=data['Survived']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %% [markdown]
# ##KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 1)

# %%
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,

# %%
from sklearn.metrics import accuracy_score

# %%
print('Model accuracy score:{0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score:0.6547

# %% [markdown]
# ##SVM Model

# %%
from sklearn import svm

# %%
model = svm.SVC(kernel = 'linear', random_state = 0, C=1.0)
model.fit(X_train, y_train)
y1_pred =model.predict(X_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,

# %%
score =accuracy_score(y_test, y1_pred)

# %%
print(score)
# Out:
# 0.7802690582959642

# %% [markdown]
# ##KFold Validation

# %%
from sklearn.model_selection import KFold

# %%
kfold_validator = KFold(10)

# %%
 for train_index, test_index in kfold_validator.split(X,y):
    print('Training Index:', train_index)
    print('Testing Index:', test_index)
# Out:
# Training Index: [ 90  91  92  93  94  95  96  97  98  99 100 101 102 103 104 105 106 107
#  108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125
#  126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143
#  144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160 161
#  162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179
#  180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197
#  198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215
#  216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233
#  234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251
#  252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269
#  270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287
#  288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
# ...

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ##Cross validatin score for knn Model

# %%
cv_result=cross_val_score(knn,X,y,cv=kfold_validator)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# ...

# %%
cv_result
# Out:
# array([0.68888889, 0.61797753, 0.73033708, 0.60674157, 0.60674157,
#        0.64044944, 0.61797753, 0.6741573 , 0.58426966, 0.69662921])

# %%
np.mean(cv_result)
# Out:
# 0.6464169787765293

# %% [markdown]
# ##Cross validatin score for SVM Model

# %%
cv_result=cross_val_score(model,X,y,cv=kfold_validator)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# ...

# %%
cv_result
# Out:
# array([0.8       , 0.80898876, 0.76404494, 0.84269663, 0.76404494,
#        0.79775281, 0.74157303, 0.74157303, 0.86516854, 0.7752809 ])

# %%
np.mean(cv_result)
# Out:
# 0.7901123595505618

# %% [markdown]
# ##Stratified Kfold Cross validation

# %%
from sklearn.model_selection import StratifiedKFold
skfold_validator =StratifiedKFold(n_splits=10)
for train_index, test_index in skfold_validator.split(X,y):
    print('Training Index:', train_index)
    print('Testing Index:', test_index)
# Out:
# Training Index: [ 82  84  85  88  94  95  96  97  98  99 100 101 102 103 104 105 106 107
#  108 109 110 111 112 113 114 115 116 117 118 119 120 121 122 123 124 125
#  126 127 128 129 130 131 132 133 134 135 136 137 138 139 140 141 142 143
#  144 145 146 147 148 149 150 151 152 153 154 155 156 157 158 159 160 161
#  162 163 164 165 166 167 168 169 170 171 172 173 174 175 176 177 178 179
#  180 181 182 183 184 185 186 187 188 189 190 191 192 193 194 195 196 197
#  198 199 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215
#  216 217 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233
#  234 235 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251
#  252 253 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269
#  270 271 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287
#  288 289 290 291 292 293 294 295 296 297 298 299 300 301 302 303 304 305
#  306 307 308 309 310 311 312 313 314 315 316 317 318 319 320 321 322 323
# ...

# %% [markdown]
# ##Stratified cross validaton for knn model

# %%
skcv_result = cross_val_score(knn,X,y,cv=skfold_validator)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:1692: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['str', 'tuple']. An error will be raised in 1.2.
#   FutureWarning,
# ...

# %%
skcv_result
# Out:
# array([0.68888889, 0.59550562, 0.70786517, 0.59550562, 0.62921348,
#        0.61797753, 0.64044944, 0.66292135, 0.59550562, 0.6741573 ])

# %%
np.mean(skcv_result)
# Out:
# 0.6407990012484395

# %% [markdown]
# ##Stratified kfold for SVM model

# %%
skcv_result = cross_val_score(model,X,y,cv=skfold_validator)

# %%
skcv_result
# Out:
# array([0.8       , 0.79775281, 0.7752809 , 0.84269663, 0.79775281,
#        0.7752809 , 0.76404494, 0.75280899, 0.83146067, 0.7752809 ])

# %%
np.mean(skcv_result)
# Out:
# 0.7912359550561798
